# %%
import os
import pymysql

connection = pymysql.connect(host='localhost',
                            user=os.getenv('CF_DB_USER', 'root'),
                            password=os.getenv('MYSQL_PASS', 'pass'),
                            db=os.getenv('CF_DB', 'testcf'),
                            charset='utf8mb4',
                            cursorclass=pymysql.cursors.DictCursor)

# %%
connection.commit()
cur = connection.cursor()
cur.execute('show tables')
# Out:
# 11

# %%
rows = cur.fetchall()
rows
# Out:
# [{'Tables_in_testcf': 'acceptance'},
#  {'Tables_in_testcf': 'competition'},
#  {'Tables_in_testcf': 'file'},
#  {'Tables_in_testcf': 'modification'},
#  {'Tables_in_testcf': 'participant'},
#  {'Tables_in_testcf': 'participantsolved'},
#  {'Tables_in_testcf': 'participantsubmission'},
#  {'Tables_in_testcf': 'problem'},
#  {'Tables_in_testcf': 'problemeditdistance'},
#  {'Tables_in_testcf': 'problemstatistics'},
#  {'Tables_in_testcf': 'submissiondistance'}]

# %%
cur.execute('select * from submissiondistance limit 100')
rows = cur.fetchall()

# %%
rows
# Out:
# [{'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-77-_19982648_707.src',
#   'levenshtein_distance': 0,
#   'move_node': 0,
#   'next_file': '-',
#   'node_sum': None,
#   'problem_id': '707A',
#   'submission_index': 1,
#   'update_node': 0,
#   'user_name': '-77-'},
#  {'add_node': 17,
#   'delete_node': 23,
#   'file_name': '-77-_19986928_707.src',
#   'levenshtein_distance': 28,
#   'move_node': 3,
#   'next_file': '-77-_19993405_707.src',
#   'node_sum': None,
#   'problem_id': '707B',
#   'submission_index': 1,
#   'update_node': 3,
#   'user_name': '-77-'},
#  {'add_node': 25,
#   'delete_node': 18,
#   'file_name': '-77-_19993405_707.src',
#   'levenshtein_distance': 30,
#   'move_node': 4,
#   'next_file': '-77-_19994367_707.src',
#   'node_sum': None,
#   'problem_id': '707B',
#   'submission_index': 2,
#   'update_node': 3,
#   'user_name': '-77-'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-77-_19994367_707.src',
#   'levenshtein_distance': 0,
#   'move_node': 0,
#   'next_file': '-',
#   'node_sum': None,
#   'problem_id': '707B',
#   'submission_index': 3,
#   'update_node': 0,
#   'user_name': '-77-'},
#  {'add_node': 5,
#   'delete_node': 0,
#   'file_name': '-77-_20001366_707.src',
#   'levenshtein_distance': 5,
#   'move_node': 0,
#   'next_file': '-77-_20006976_707.src',
#   'node_sum': None,
#   'problem_id': '707C',
#   'submission_index': 1,
#   'update_node': 1,
#   'user_name': '-77-'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-77-_20006976_707.src',
#   'levenshtein_distance': 1,
#   'move_node': 0,
#   'next_file': '-77-_20008007_707.src',
#   'node_sum': None,
#   'problem_id': '707C',
#   'submission_index': 2,
#   'update_node': 1,
#   'user_name': '-77-'},
#  {'add_node': 2,
#   'delete_node': 2,
#   'file_name': '-77-_20008007_707.src',
#   'levenshtein_distance': 16,
#   'move_node': 3,
#   'next_file': '-77-_20008074_707.src',
#   'node_sum': None,
#   'problem_id': '707C',
#   'submission_index': 3,
#   'update_node': 0,
#   'user_name': '-77-'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-77-_20008074_707.src',
#   'levenshtein_distance': 1,
#   'move_node': 0,
#   'next_file': '-77-_20008122_707.src',
#   'node_sum': None,
#   'problem_id': '707C',
#   'submission_index': 4,
#   'update_node': 1,
#   'user_name': '-77-'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-77-_20008122_707.src',
#   'levenshtein_distance': 1,
#   'move_node': 0,
#   'next_file': '-77-_20008152_707.src',
#   'node_sum': None,
#   'problem_id': '707C',
#   'submission_index': 5,
#   'update_node': 1,
#   'user_name': '-77-'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-77-_20008152_707.src',
#   'levenshtein_distance': 4,
#   'move_node': 0,
#   'next_file': '-77-_20008225_707.src',
#   'node_sum': None,
#   'problem_id': '707C',
#   'submission_index': 6,
#   'update_node': 4,
#   'user_name': '-77-'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-77-_20008225_707.src',
#   'levenshtein_distance': 0,
#   'move_node': 0,
#   'next_file': '-',
#   'node_sum': None,
#   'problem_id': '707C',
#   'submission_index': 7,
#   'update_node': 0,
#   'user_name': '-77-'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-77-_21019682_721.src',
#   'levenshtein_distance': 0,
#   'move_node': 0,
#   'next_file': '-',
#   'node_sum': None,
#   'problem_id': '721A',
#   'submission_index': 1,
#   'update_node': 0,
#   'user_name': '-77-'},
#  {'add_node': 2,
#   'delete_node': 1,
#   'file_name': '-77-_21024470_721.src',
#   'levenshtein_distance': 7,
#   'move_node': 0,
#   'next_file': '-77-_21044325_721.src',
#   'node_sum': None,
#   'problem_id': '721B',
#   'submission_index': 1,
#   'update_node': 4,
#   'user_name': '-77-'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-77-_21031728_721.src',
#   'levenshtein_distance': 0,
#   'move_node': 0,
#   'next_file': '-',
#   'node_sum': None,
#   'problem_id': '721C',
#   'submission_index': 1,
#   'update_node': 0,
#   'user_name': '-77-'},
#  {'add_node': 237,
#   'delete_node': 1,
#   'file_name': '-77-_21038957_721.src',
#   'levenshtein_distance': 178,
#   'move_node': 2,
#   'next_file': '-77-_21039865_721.src',
#   'node_sum': None,
#   'problem_id': '721D',
#   'submission_index': 1,
#   'update_node': 0,
#   'user_name': '-77-'},
#  {'add_node': 10,
#   'delete_node': 0,
#   'file_name': '-77-_21039865_721.src',
#   'levenshtein_distance': 6,
#   'move_node': 2,
#   'next_file': '-77-_21040114_721.src',
#   'node_sum': None,
#   'problem_id': '721D',
#   'submission_index': 2,
#   'update_node': 0,
#   'user_name': '-77-'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-77-_21040114_721.src',
#   'levenshtein_distance': 0,
#   'move_node': 0,
#   'next_file': '-',
#   'node_sum': None,
#   'problem_id': '721D',
#   'submission_index': 3,
#   'update_node': 0,
#   'user_name': '-77-'},
#  {'add_node': 2,
#   'delete_node': 2,
#   'file_name': '-77-_21044325_721.src',
#   'levenshtein_distance': 2,
#   'move_node': 0,
#   'next_file': '-77-_21045529_721.src',
#   'node_sum': None,
#   'problem_id': '721B',
#   'submission_index': 2,
#   'update_node': 0,
#   'user_name': '-77-'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-77-_21045529_721.src',
#   'levenshtein_distance': 0,
#   'move_node': 0,
#   'next_file': '-',
#   'node_sum': None,
#   'problem_id': '721B',
#   'submission_index': 3,
#   'update_node': 0,
#   'user_name': '-77-'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_18486440_189.src',
#   'levenshtein_distance': 0,
#   'move_node': 0,
#   'next_file': '-Ahmed_18486444_189.src',
#   'node_sum': None,
#   'problem_id': '189A',
#   'submission_index': 1,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_18486444_189.src',
#   'levenshtein_distance': 2,
#   'move_node': 0,
#   'next_file': '-Ahmed_18486574_189.src',
#   'node_sum': None,
#   'problem_id': '189A',
#   'submission_index': 2,
#   'update_node': 2,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_18486574_189.src',
#   'levenshtein_distance': 0,
#   'move_node': 0,
#   'next_file': '-',
#   'node_sum': None,
#   'problem_id': '189A',
#   'submission_index': 3,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_18525018_431.src',
#   'levenshtein_distance': 0,
#   'move_node': 0,
#   'next_file': '-',
#   'node_sum': None,
#   'problem_id': '431C',
#   'submission_index': 1,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 7,
#   'delete_node': 3,
#   'file_name': '-Ahmed_18533935_118.src',
#   'levenshtein_distance': 3,
#   'move_node': 1,
#   'next_file': '-Ahmed_18534197_118.src',
#   'node_sum': None,
#   'problem_id': '118D',
#   'submission_index': 1,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_18534197_118.src',
#   'levenshtein_distance': 0,
#   'move_node': 0,
#   'next_file': '-',
#   'node_sum': None,
#   'problem_id': '118D',
#   'submission_index': 2,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_18571161_545.src',
#   'levenshtein_distance': 0,
#   'move_node': 0,
#   'next_file': '-',
#   'node_sum': None,
#   'problem_id': '545C',
#   'submission_index': 1,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_18637239_104.src',
#   'levenshtein_distance': 1,
#   'move_node': 0,
#   'next_file': '-Ahmed_18637247_104.src',
#   'node_sum': None,
#   'problem_id': '104C',
#   'submission_index': 1,
#   'update_node': 1,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_18637247_104.src',
#   'levenshtein_distance': 0,
#   'move_node': 0,
#   'next_file': '-',
#   'node_sum': None,
#   'problem_id': '104C',
#   'submission_index': 2,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 1,
#   'delete_node': 0,
#   'file_name': '-Ahmed_18637432_445.src',
#   'levenshtein_distance': 2,
#   'move_node': 0,
#   'next_file': '-Ahmed_18637859_445.src',
#   'node_sum': None,
#   'problem_id': '445B',
#   'submission_index': 1,
#   'update_node': 1,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_18637859_445.src',
#   'levenshtein_distance': 0,
#   'move_node': 0,
#   'next_file': '-',
#   'node_sum': None,
#   'problem_id': '445B',
#   'submission_index': 2,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_18653439_25.src',
#   'levenshtein_distance': 0,
#   'move_node': 0,
#   'next_file': '-',
#   'node_sum': None,
#   'problem_id': '25D',
#   'submission_index': 1,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_18687128_17.src',
#   'levenshtein_distance': 3,
#   'move_node': 2,
#   'next_file': '-Ahmed_18687341_17.src',
#   'node_sum': None,
#   'problem_id': '17B',
#   'submission_index': 1,
#   'update_node': 1,
#   'user_name': '-Ahmed'},
#  {'add_node': 27,
#   'delete_node': 0,
#   'file_name': '-Ahmed_18687341_17.src',
#   'levenshtein_distance': 25,
#   'move_node': 7,
#   'next_file': '-Ahmed_18687723_17.src',
#   'node_sum': None,
#   'problem_id': '17B',
#   'submission_index': 2,
#   'update_node': 2,
#   'user_name': '-Ahmed'},
#  {'add_node': 2,
#   'delete_node': 48,
#   'file_name': '-Ahmed_18687723_17.src',
#   'levenshtein_distance': 34,
#   'move_node': 0,
#   'next_file': '-Ahmed_18687871_17.src',
#   'node_sum': None,
#   'problem_id': '17B',
#   'submission_index': 3,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 126,
#   'delete_node': 166,
#   'file_name': '-Ahmed_18687871_17.src',
#   'levenshtein_distance': 196,
#   'move_node': 27,
#   'next_file': '-Ahmed_18692105_17.src',
#   'node_sum': None,
#   'problem_id': '17B',
#   'submission_index': 4,
#   'update_node': 23,
#   'user_name': '-Ahmed'},
#  {'add_node': 8,
#   'delete_node': 9,
#   'file_name': '-Ahmed_18692105_17.src',
#   'levenshtein_distance': 12,
#   'move_node': 6,
#   'next_file': '-Ahmed_18692127_17.src',
#   'node_sum': None,
#   'problem_id': '17B',
#   'submission_index': 5,
#   'update_node': 3,
#   'user_name': '-Ahmed'},
#  {'add_node': 40,
#   'delete_node': 0,
#   'file_name': '-Ahmed_18692127_17.src',
#   'levenshtein_distance': 29,
#   'move_node': 0,
#   'next_file': '-Ahmed_18692168_17.src',
#   'node_sum': None,
#   'problem_id': '17B',
#   'submission_index': 6,
#   'update_node': 2,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 4,
#   'file_name': '-Ahmed_18692168_17.src',
#   'levenshtein_distance': 5,
#   'move_node': 0,
#   'next_file': '-Ahmed_18692231_17.src',
#   'node_sum': None,
#   'problem_id': '17B',
#   'submission_index': 7,
#   'update_node': 2,
#   'user_name': '-Ahmed'},
#  {'add_node': 125,
#   'delete_node': 176,
#   'file_name': '-Ahmed_18692231_17.src',
#   'levenshtein_distance': 274,
#   'move_node': 42,
#   'next_file': '-Ahmed_18693167_17.src',
#   'node_sum': None,
#   'problem_id': '17B',
#   'submission_index': 8,
#   'update_node': 46,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_18693167_17.src',
#   'levenshtein_distance': 0,
#   'move_node': 0,
#   'next_file': '-',
#   'node_sum': None,
#   'problem_id': '17B',
#   'submission_index': 9,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_18693791_505.src',
#   'levenshtein_distance': 0,
#   'move_node': 0,
#   'next_file': '-',
#   'node_sum': None,
#   'problem_id': '505B',
#   'submission_index': 1,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 63,
#   'delete_node': 9,
#   'file_name': '-Ahmed_18694507_472.src',
#   'levenshtein_distance': 40,
#   'move_node': 3,
#   'next_file': '-Ahmed_18702073_472.src',
#   'node_sum': None,
#   'problem_id': '472D',
#   'submission_index': 1,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 7,
#   'delete_node': 23,
#   'file_name': '-Ahmed_18702073_472.src',
#   'levenshtein_distance': 15,
#   'move_node': 5,
#   'next_file': '-Ahmed_18702098_472.src',
#   'node_sum': None,
#   'problem_id': '472D',
#   'submission_index': 2,
#   'update_node': 1,
#   'user_name': '-Ahmed'},
#  {'add_node': 132,
#   'delete_node': 73,
#   'file_name': '-Ahmed_18702098_472.src',
#   'levenshtein_distance': 158,
#   'move_node': 12,
#   'next_file': '-Ahmed_18702836_472.src',
#   'node_sum': None,
#   'problem_id': '472D',
#   'submission_index': 3,
#   'update_node': 10,
#   'user_name': '-Ahmed'},
#  {'add_node': 28,
#   'delete_node': 0,
#   'file_name': '-Ahmed_18702836_472.src',
#   'levenshtein_distance': 22,
#   'move_node': 0,
#   'next_file': '-Ahmed_18702884_472.src',
#   'node_sum': None,
#   'problem_id': '472D',
#   'submission_index': 4,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_18702884_472.src',
#   'levenshtein_distance': 1,
#   'move_node': 0,
#   'next_file': '-Ahmed_18702918_472.src',
#   'node_sum': None,
#   'problem_id': '472D',
#   'submission_index': 5,
#   'update_node': 1,
#   'user_name': '-Ahmed'},
#  {'add_node': 53,
#   'delete_node': 46,
#   'file_name': '-Ahmed_18702918_472.src',
#   'levenshtein_distance': 88,
#   'move_node': 2,
#   'next_file': '-Ahmed_18703092_472.src',
#   'node_sum': None,
#   'problem_id': '472D',
#   'submission_index': 6,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_18703092_472.src',
#   'levenshtein_distance': 0,
#   'move_node': 0,
#   'next_file': '-',
#   'node_sum': None,
#   'problem_id': '472D',
#   'submission_index': 7,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_18749457_19.src',
#   'levenshtein_distance': 1,
#   'move_node': 0,
#   'next_file': '-Ahmed_18749467_19.src',
#   'node_sum': None,
#   'problem_id': '19B',
#   'submission_index': 1,
#   'update_node': 1,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_18749467_19.src',
#   'levenshtein_distance': 2,
#   'move_node': 0,
#   'next_file': '-Ahmed_18749493_19.src',
#   'node_sum': None,
#   'problem_id': '19B',
#   'submission_index': 2,
#   'update_node': 2,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_18749493_19.src',
#   'levenshtein_distance': 1,
#   'move_node': 0,
#   'next_file': '-Ahmed_18749499_19.src',
#   'node_sum': None,
#   'problem_id': '19B',
#   'submission_index': 3,
#   'update_node': 1,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_18749499_19.src',
#   'levenshtein_distance': 1,
#   'move_node': 0,
#   'next_file': '-Ahmed_18749501_19.src',
#   'node_sum': None,
#   'problem_id': '19B',
#   'submission_index': 4,
#   'update_node': 1,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_18749501_19.src',
#   'levenshtein_distance': 1,
#   'move_node': 0,
#   'next_file': '-Ahmed_18749503_19.src',
#   'node_sum': None,
#   'problem_id': '19B',
#   'submission_index': 5,
#   'update_node': 1,
#   'user_name': '-Ahmed'},
#  {'add_node': 5,
#   'delete_node': 27,
#   'file_name': '-Ahmed_18749503_19.src',
#   'levenshtein_distance': 40,
#   'move_node': 5,
#   'next_file': '-Ahmed_18759105_19.src',
#   'node_sum': None,
#   'problem_id': '19B',
#   'submission_index': 6,
#   'update_node': 10,
#   'user_name': '-Ahmed'},
#  {'add_node': 8,
#   'delete_node': 0,
#   'file_name': '-Ahmed_18759105_19.src',
#   'levenshtein_distance': 12,
#   'move_node': 1,
#   'next_file': '-Ahmed_18759119_19.src',
#   'node_sum': None,
#   'problem_id': '19B',
#   'submission_index': 7,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_18759119_19.src',
#   'levenshtein_distance': 0,
#   'move_node': 0,
#   'next_file': '-',
#   'node_sum': None,
#   'problem_id': '19B',
#   'submission_index': 8,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_18777535_35.src',
#   'levenshtein_distance': 2,
#   'move_node': 0,
#   'next_file': '-Ahmed_18777539_35.src',
#   'node_sum': None,
#   'problem_id': '35D',
#   'submission_index': 1,
#   'update_node': 2,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_18777539_35.src',
#   'levenshtein_distance': 1,
#   'move_node': 0,
#   'next_file': '-Ahmed_18777547_35.src',
#   'node_sum': None,
#   'problem_id': '35D',
#   'submission_index': 2,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_18777547_35.src',
#   'levenshtein_distance': 0,
#   'move_node': 0,
#   'next_file': '-',
#   'node_sum': None,
#   'problem_id': '35D',
#   'submission_index': 3,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_18841379_678.src',
#   'levenshtein_distance': 0,
#   'move_node': 0,
#   'next_file': '-',
#   'node_sum': None,
#   'problem_id': '678E',
#   'submission_index': 1,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 125,
#   'delete_node': 32,
#   'file_name': '-Ahmed_18878169_167.src',
#   'levenshtein_distance': 111,
#   'move_node': 3,
#   'next_file': '-Ahmed_18878568_167.src',
#   'node_sum': None,
#   'problem_id': '167B',
#   'submission_index': 1,
#   'update_node': 3,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_18878568_167.src',
#   'levenshtein_distance': 0,
#   'move_node': 0,
#   'next_file': '-',
#   'node_sum': None,
#   'problem_id': '167B',
#   'submission_index': 2,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_18991529_688.src',
#   'levenshtein_distance': 0,
#   'move_node': 0,
#   'next_file': '-',
#   'node_sum': None,
#   'problem_id': '688A',
#   'submission_index': 1,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 9,
#   'delete_node': 0,
#   'file_name': '-Ahmed_19096208_115.src',
#   'levenshtein_distance': 7,
#   'move_node': 0,
#   'next_file': '-Ahmed_19096265_115.src',
#   'node_sum': None,
#   'problem_id': '115A',
#   'submission_index': 1,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 97,
#   'delete_node': 82,
#   'file_name': '-Ahmed_19096265_115.src',
#   'levenshtein_distance': 127,
#   'move_node': 11,
#   'next_file': '-Ahmed_19096477_115.src',
#   'node_sum': None,
#   'problem_id': '115A',
#   'submission_index': 2,
#   'update_node': 9,
#   'user_name': '-Ahmed'},
#  {'add_node': 63,
#   'delete_node': 108,
#   'file_name': '-Ahmed_19096477_115.src',
#   'levenshtein_distance': 117,
#   'move_node': 2,
#   'next_file': '-Ahmed_19096602_115.src',
#   'node_sum': None,
#   'problem_id': '115A',
#   'submission_index': 3,
#   'update_node': 1,
#   'user_name': '-Ahmed'},
#  {'add_node': 46,
#   'delete_node': 0,
#   'file_name': '-Ahmed_19096602_115.src',
#   'levenshtein_distance': 36,
#   'move_node': 1,
#   'next_file': '-Ahmed_19096623_115.src',
#   'node_sum': None,
#   'problem_id': '115A',
#   'submission_index': 4,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_19096623_115.src',
#   'levenshtein_distance': 0,
#   'move_node': 0,
#   'next_file': '-',
#   'node_sum': None,
#   'problem_id': '115A',
#   'submission_index': 5,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_19096788_353.src',
#   'levenshtein_distance': 0,
#   'move_node': 0,
#   'next_file': '-',
#   'node_sum': None,
#   'problem_id': '353A',
#   'submission_index': 1,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_19172673_687.src',
#   'levenshtein_distance': 0,
#   'move_node': 0,
#   'next_file': '-',
#   'node_sum': None,
#   'problem_id': '687A',
#   'submission_index': 1,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 16,
#   'delete_node': 13,
#   'file_name': '-Ahmed_19178698_35.src',
#   'levenshtein_distance': 48,
#   'move_node': 5,
#   'next_file': '-Ahmed_19178852_35.src',
#   'node_sum': None,
#   'problem_id': '35C',
#   'submission_index': 1,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 2,
#   'delete_node': 19,
#   'file_name': '-Ahmed_19178852_35.src',
#   'levenshtein_distance': 13,
#   'move_node': 0,
#   'next_file': '-Ahmed_19178886_35.src',
#   'node_sum': None,
#   'problem_id': '35C',
#   'submission_index': 2,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 57,
#   'delete_node': 13,
#   'file_name': '-Ahmed_19178886_35.src',
#   'levenshtein_distance': 35,
#   'move_node': 4,
#   'next_file': '-Ahmed_19180452_35.src',
#   'node_sum': None,
#   'problem_id': '35C',
#   'submission_index': 3,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 16,
#   'delete_node': 59,
#   'file_name': '-Ahmed_19180452_35.src',
#   'levenshtein_distance': 158,
#   'move_node': 7,
#   'next_file': '-Ahmed_19180469_35.src',
#   'node_sum': None,
#   'problem_id': '35C',
#   'submission_index': 4,
#   'update_node': 3,
#   'user_name': '-Ahmed'},
#  {'add_node': 82,
#   'delete_node': 176,
#   'file_name': '-Ahmed_19180469_35.src',
#   'levenshtein_distance': 190,
#   'move_node': 23,
#   'next_file': '-Ahmed_19180616_35.src',
#   'node_sum': None,
#   'problem_id': '35C',
#   'submission_index': 5,
#   'update_node': 28,
#   'user_name': '-Ahmed'},
#  {'add_node': 253,
#   'delete_node': 139,
#   'file_name': '-Ahmed_19180616_35.src',
#   'levenshtein_distance': 284,
#   'move_node': 19,
#   'next_file': '-Ahmed_19180630_35.src',
#   'node_sum': None,
#   'problem_id': '35C',
#   'submission_index': 6,
#   'update_node': 11,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_19180630_35.src',
#   'levenshtein_distance': 0,
#   'move_node': 0,
#   'next_file': '-',
#   'node_sum': None,
#   'problem_id': '35C',
#   'submission_index': 7,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 138,
#   'delete_node': 1,
#   'file_name': '-Ahmed_19236440_699.src',
#   'levenshtein_distance': 108,
#   'move_node': 4,
#   'next_file': '-Ahmed_19238544_699.src',
#   'node_sum': None,
#   'problem_id': '699A',
#   'submission_index': 1,
#   'update_node': 2,
#   'user_name': '-Ahmed'},
#  {'add_node': 24,
#   'delete_node': 41,
#   'file_name': '-Ahmed_19238544_699.src',
#   'levenshtein_distance': 78,
#   'move_node': 22,
#   'next_file': '-Ahmed_19240455_699.src',
#   'node_sum': None,
#   'problem_id': '699A',
#   'submission_index': 2,
#   'update_node': 6,
#   'user_name': '-Ahmed'},
#  {'add_node': 9,
#   'delete_node': 31,
#   'file_name': '-Ahmed_19240455_699.src',
#   'levenshtein_distance': 42,
#   'move_node': 8,
#   'next_file': '-Ahmed_19241172_699.src',
#   'node_sum': None,
#   'problem_id': '699A',
#   'submission_index': 3,
#   'update_node': 10,
#   'user_name': '-Ahmed'},
#  {'add_node': 33,
#   'delete_node': 0,
#   'file_name': '-Ahmed_19241172_699.src',
#   'levenshtein_distance': 21,
#   'move_node': 0,
#   'next_file': '-Ahmed_19242076_699.src',
#   'node_sum': None,
#   'problem_id': '699A',
#   'submission_index': 4,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 30,
#   'delete_node': 71,
#   'file_name': '-Ahmed_19242076_699.src',
#   'levenshtein_distance': 58,
#   'move_node': 27,
#   'next_file': '-Ahmed_19244633_699.src',
#   'node_sum': None,
#   'problem_id': '699A',
#   'submission_index': 5,
#   'update_node': 13,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_19244633_699.src',
#   'levenshtein_distance': 0,
#   'move_node': 0,
#   'next_file': '-',
#   'node_sum': None,
#   'problem_id': '699A',
#   'submission_index': 6,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 2,
#   'delete_node': 0,
#   'file_name': '-Ahmed_19257701_699.src',
#   'levenshtein_distance': 2,
#   'move_node': 0,
#   'next_file': '-Ahmed_19257782_699.src',
#   'node_sum': None,
#   'problem_id': '699B',
#   'submission_index': 1,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 3,
#   'delete_node': 0,
#   'file_name': '-Ahmed_19257782_699.src',
#   'levenshtein_distance': 29,
#   'move_node': 2,
#   'next_file': '-Ahmed_19258682_699.src',
#   'node_sum': None,
#   'problem_id': '699B',
#   'submission_index': 2,
#   'update_node': 1,
#   'user_name': '-Ahmed'},
#  {'add_node': 79,
#   'delete_node': 618,
#   'file_name': '-Ahmed_19258682_699.src',
#   'levenshtein_distance': 484,
#   'move_node': 43,
#   'next_file': '-Ahmed_20679842_699.src',
#   'node_sum': None,
#   'problem_id': '699B',
#   'submission_index': 3,
#   'update_node': 30,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_19271592_699.src',
#   'levenshtein_distance': 0,
#   'move_node': 0,
#   'next_file': '-',
#   'node_sum': None,
#   'problem_id': '699C',
#   'submission_index': 1,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 47,
#   'delete_node': 4,
#   'file_name': '-Ahmed_19284540_659.src',
#   'levenshtein_distance': 42,
#   'move_node': 6,
#   'next_file': '-Ahmed_19285429_659.src',
#   'node_sum': None,
#   'problem_id': '659E',
#   'submission_index': 1,
#   'update_node': 5,
#   'user_name': '-Ahmed'},
#  {'add_node': 11,
#   'delete_node': 0,
#   'file_name': '-Ahmed_19285429_659.src',
#   'levenshtein_distance': 8,
#   'move_node': 0,
#   'next_file': '-Ahmed_19285502_659.src',
#   'node_sum': None,
#   'problem_id': '659E',
#   'submission_index': 2,
#   'update_node': 1,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_19285502_659.src',
#   'levenshtein_distance': 0,
#   'move_node': 0,
#   'next_file': '-',
#   'node_sum': None,
#   'problem_id': '659E',
#   'submission_index': 3,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_19346013_701.src',
#   'levenshtein_distance': 0,
#   'move_node': 0,
#   'next_file': '-',
#   'node_sum': None,
#   'problem_id': '701A',
#   'submission_index': 1,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 99,
#   'delete_node': 362,
#   'file_name': '-Ahmed_19351636_701.src',
#   'levenshtein_distance': 279,
#   'move_node': 29,
#   'next_file': '-Ahmed_19384073_701.src',
#   'node_sum': None,
#   'problem_id': '701C',
#   'submission_index': 1,
#   'update_node': 19,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_19384073_701.src',
#   'levenshtein_distance': 0,
#   'move_node': 0,
#   'next_file': '-',
#   'node_sum': None,
#   'problem_id': '701C',
#   'submission_index': 2,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_19410533_295.src',
#   'levenshtein_distance': 5,
#   'move_node': 0,
#   'next_file': '-Ahmed_19411325_295.src',
#   'node_sum': None,
#   'problem_id': '295B',
#   'submission_index': 1,
#   'update_node': 5,
#   'user_name': '-Ahmed'},
#  {'add_node': 30,
#   'delete_node': 97,
#   'file_name': '-Ahmed_19411325_295.src',
#   'levenshtein_distance': 90,
#   'move_node': 2,
#   'next_file': '-Ahmed_19411449_295.src',
#   'node_sum': None,
#   'problem_id': '295B',
#   'submission_index': 2,
#   'update_node': 6,
#   'user_name': '-Ahmed'},
#  {'add_node': 195,
#   'delete_node': 276,
#   'file_name': '-Ahmed_19411449_295.src',
#   'levenshtein_distance': 284,
#   'move_node': 62,
#   'next_file': '-Ahmed_19413617_295.src',
#   'node_sum': None,
#   'problem_id': '295B',
#   'submission_index': 3,
#   'update_node': 34,
#   'user_name': '-Ahmed'},
#  {'add_node': 9,
#   'delete_node': 5,
#   'file_name': '-Ahmed_19413617_295.src',
#   'levenshtein_distance': 32,
#   'move_node': 3,
#   'next_file': '-Ahmed_19413664_295.src',
#   'node_sum': None,
#   'problem_id': '295B',
#   'submission_index': 4,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 0,
#   'delete_node': 0,
#   'file_name': '-Ahmed_19413664_295.src',
#   'levenshtein_distance': 0,
#   'move_node': 0,
#   'next_file': '-',
#   'node_sum': None,
#   'problem_id': '295B',
#   'submission_index': 5,
#   'update_node': 0,
#   'user_name': '-Ahmed'},
#  {'add_node': 707,
#   'delete_node': 332,
#   'file_name': '-Ahmed_19425810_507.src',
#   'levenshtein_distance': 647,
#   'move_node': 112,
#   'next_file': '-Ahmed_20566605_507.src',
#   'node_sum': None,
#   'problem_id': '507E',
#   'submission_index': 1,
#   'update_node': 102,
#   'user_name': '-Ahmed'},
#  {'add_node': 4,
#   'delete_node': 0,
#   'file_name': '-Ahmed_19450214_449.src',
#   'levenshtein_distance': 24,
#   'move_node': 2,
#   'next_file': '-Ahmed_19450304_449.src',
#   'node_sum': None,
#   'problem_id': '449B',
#   'submission_index': 1,
#   'update_node': 19,
#   'user_name': '-Ahmed'}]

# %%
cur.execute('select * from modification limit 100')
rows = cur.fetchall()

# %%
rows
# Out:
# [{'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974710_621.src',
#   'idx': '179747100100000',
#   'modification_type': 'INS',
#   'node_type': 'else',
#   'parent_type': 'if',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974710_621.src',
#   'idx': '179747100100001',
#   'modification_type': 'INS',
#   'node_type': 'block',
#   'parent_type': 'else',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974710_621.src',
#   'idx': '179747100100002',
#   'modification_type': 'INS',
#   'node_type': 'expr_stmt',
#   'parent_type': 'block',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974710_621.src',
#   'idx': '179747100100003',
#   'modification_type': 'INS',
#   'node_type': 'expr',
#   'parent_type': 'expr_stmt',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974710_621.src',
#   'idx': '179747100100004',
#   'modification_type': 'INS',
#   'node_type': 'name',
#   'parent_type': 'expr',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974710_621.src',
#   'idx': '179747100100005',
#   'modification_type': 'INS',
#   'node_type': 'operator',
#   'parent_type': 'expr',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974710_621.src',
#   'idx': '179747100100006',
#   'modification_type': 'INS',
#   'node_type': 'name',
#   'parent_type': 'expr',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974710_621.src',
#   'idx': '179747100100007',
#   'modification_type': 'INS',
#   'node_type': 'operator',
#   'parent_type': 'expr',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974710_621.src',
#   'idx': '179747100100008',
#   'modification_type': 'INS',
#   'node_type': 'name',
#   'parent_type': 'expr',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200000',
#   'modification_type': 'INS',
#   'node_type': 'decl_stmt',
#   'parent_type': 'block',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200001',
#   'modification_type': 'INS',
#   'node_type': 'for',
#   'parent_type': 'block',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200002',
#   'modification_type': 'INS',
#   'node_type': 'for',
#   'parent_type': 'block',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200003',
#   'modification_type': 'INS',
#   'node_type': 'for',
#   'parent_type': 'block',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200004',
#   'modification_type': 'MOV',
#   'node_type': 'expr_stmt',
#   'parent_type': 'block',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200005',
#   'modification_type': 'INS',
#   'node_type': 'decl',
#   'parent_type': 'decl_stmt',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200006',
#   'modification_type': 'INS',
#   'node_type': 'decl',
#   'parent_type': 'decl_stmt',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200007',
#   'modification_type': 'MOV',
#   'node_type': 'decl',
#   'parent_type': 'decl_stmt',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200008',
#   'modification_type': 'INS',
#   'node_type': 'decl',
#   'parent_type': 'decl_stmt',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200009',
#   'modification_type': 'INS',
#   'node_type': 'decl',
#   'parent_type': 'decl_stmt',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200010',
#   'modification_type': 'INS',
#   'node_type': 'control',
#   'parent_type': 'for',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200011',
#   'modification_type': 'MOV',
#   'node_type': 'block',
#   'parent_type': 'for',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200012',
#   'modification_type': 'INS',
#   'node_type': 'control',
#   'parent_type': 'for',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200013',
#   'modification_type': 'INS',
#   'node_type': 'block',
#   'parent_type': 'for',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200014',
#   'modification_type': 'MOV',
#   'node_type': 'control',
#   'parent_type': 'for',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200015',
#   'modification_type': 'INS',
#   'node_type': 'block',
#   'parent_type': 'for',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200016',
#   'modification_type': 'UPD',
#   'node_type': 'name',
#   'parent_type': 'decl',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200017',
#   'modification_type': 'UPD',
#   'node_type': 'name',
#   'parent_type': 'decl',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200018',
#   'modification_type': 'INS',
#   'node_type': 'type',
#   'parent_type': 'decl',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200019',
#   'modification_type': 'INS',
#   'node_type': 'name',
#   'parent_type': 'decl',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200020',
#   'modification_type': 'INS',
#   'node_type': 'init',
#   'parent_type': 'decl',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200021',
#   'modification_type': 'INS',
#   'node_type': 'type',
#   'parent_type': 'decl',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200022',
#   'modification_type': 'INS',
#   'node_type': 'name',
#   'parent_type': 'decl',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200023',
#   'modification_type': 'INS',
#   'node_type': 'init',
#   'parent_type': 'decl',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200024',
#   'modification_type': 'UPD',
#   'node_type': 'name',
#   'parent_type': 'decl',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200025',
#   'modification_type': 'UPD',
#   'node_type': 'name',
#   'parent_type': 'decl',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200026',
#   'modification_type': 'UPD',
#   'node_type': 'name',
#   'parent_type': 'expr',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200027',
#   'modification_type': 'INS',
#   'node_type': 'operator',
#   'parent_type': 'expr',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200028',
#   'modification_type': 'INS',
#   'node_type': 'name',
#   'parent_type': 'expr',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200029',
#   'modification_type': 'INS',
#   'node_type': 'type',
#   'parent_type': 'decl',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200030',
#   'modification_type': 'INS',
#   'node_type': 'name',
#   'parent_type': 'decl',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200031',
#   'modification_type': 'INS',
#   'node_type': 'type',
#   'parent_type': 'decl',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200032',
#   'modification_type': 'INS',
#   'node_type': 'name',
#   'parent_type': 'decl',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200033',
#   'modification_type': 'INS',
#   'node_type': 'init',
#   'parent_type': 'control',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200034',
#   'modification_type': 'INS',
#   'node_type': 'condition',
#   'parent_type': 'control',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200035',
#   'modification_type': 'INS',
#   'node_type': 'incr',
#   'parent_type': 'control',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200036',
#   'modification_type': 'INS',
#   'node_type': 'init',
#   'parent_type': 'control',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200037',
#   'modification_type': 'INS',
#   'node_type': 'condition',
#   'parent_type': 'control',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200038',
#   'modification_type': 'INS',
#   'node_type': 'incr',
#   'parent_type': 'control',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200039',
#   'modification_type': 'INS',
#   'node_type': 'for',
#   'parent_type': 'block',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200040',
#   'modification_type': 'INS',
#   'node_type': 'if',
#   'parent_type': 'block',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200041',
#   'modification_type': 'INS',
#   'node_type': 'expr_stmt',
#   'parent_type': 'block',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200042',
#   'modification_type': 'INS',
#   'node_type': 'init',
#   'parent_type': 'control',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200043',
#   'modification_type': 'INS',
#   'node_type': 'for',
#   'parent_type': 'block',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200044',
#   'modification_type': 'INS',
#   'node_type': 'if',
#   'parent_type': 'block',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200045',
#   'modification_type': 'MOV',
#   'node_type': 'expr_stmt',
#   'parent_type': 'block',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200046',
#   'modification_type': 'INS',
#   'node_type': 'operator',
#   'parent_type': 'expr',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200047',
#   'modification_type': 'INS',
#   'node_type': 'operator',
#   'parent_type': 'expr',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200048',
#   'modification_type': 'UPD',
#   'node_type': 'name',
#   'parent_type': 'expr',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200049',
#   'modification_type': 'INS',
#   'node_type': 'operator',
#   'parent_type': 'expr',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200050',
#   'modification_type': 'INS',
#   'node_type': 'name',
#   'parent_type': 'expr',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200051',
#   'modification_type': 'INS',
#   'node_type': 'operator',
#   'parent_type': 'expr',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200052',
#   'modification_type': 'INS',
#   'node_type': 'operator',
#   'parent_type': 'expr',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200053',
#   'modification_type': 'INS',
#   'node_type': 'name',
#   'parent_type': 'expr',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200054',
#   'modification_type': 'INS',
#   'node_type': 'operator',
#   'parent_type': 'expr',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200055',
#   'modification_type': 'INS',
#   'node_type': 'operator',
#   'parent_type': 'expr',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200056',
#   'modification_type': 'INS',
#   'node_type': 'name',
#   'parent_type': 'expr',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200057',
#   'modification_type': 'INS',
#   'node_type': 'expr',
#   'parent_type': 'init',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200058',
#   'modification_type': 'INS',
#   'node_type': 'expr',
#   'parent_type': 'init',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200059',
#   'modification_type': 'UPD',
#   'node_type': 'name',
#   'parent_type': 'type',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200060',
#   'modification_type': 'UPD',
#   'node_type': 'name',
#   'parent_type': 'name',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200061',
#   'modification_type': 'INS',
#   'node_type': 'name',
#   'parent_type': 'type',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200062',
#   'modification_type': 'INS',
#   'node_type': 'expr',
#   'parent_type': 'init',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200063',
#   'modification_type': 'INS',
#   'node_type': 'expr',
#   'parent_type': 'condition',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200064',
#   'modification_type': 'INS',
#   'node_type': 'expr',
#   'parent_type': 'incr',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200065',
#   'modification_type': 'INS',
#   'node_type': 'expr',
#   'parent_type': 'init',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200066',
#   'modification_type': 'INS',
#   'node_type': 'expr',
#   'parent_type': 'condition',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200067',
#   'modification_type': 'INS',
#   'node_type': 'expr',
#   'parent_type': 'incr',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200068',
#   'modification_type': 'INS',
#   'node_type': 'control',
#   'parent_type': 'for',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200069',
#   'modification_type': 'MOV',
#   'node_type': 'block',
#   'parent_type': 'for',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200070',
#   'modification_type': 'INS',
#   'node_type': 'condition',
#   'parent_type': 'if',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200071',
#   'modification_type': 'INS',
#   'node_type': 'then',
#   'parent_type': 'if',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200072',
#   'modification_type': 'INS',
#   'node_type': 'expr',
#   'parent_type': 'expr_stmt',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200073',
#   'modification_type': 'MOV',
#   'node_type': 'expr',
#   'parent_type': 'init',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200074',
#   'modification_type': 'INS',
#   'node_type': 'control',
#   'parent_type': 'for',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200075',
#   'modification_type': 'INS',
#   'node_type': 'block',
#   'parent_type': 'for',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200076',
#   'modification_type': 'INS',
#   'node_type': 'condition',
#   'parent_type': 'if',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200077',
#   'modification_type': 'INS',
#   'node_type': 'then',
#   'parent_type': 'if',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200078',
#   'modification_type': 'INS',
#   'node_type': 'literal',
#   'parent_type': 'expr',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200079',
#   'modification_type': 'INS',
#   'node_type': 'literal',
#   'parent_type': 'expr',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200080',
#   'modification_type': 'UPD',
#   'node_type': 'name',
#   'parent_type': 'expr',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200081',
#   'modification_type': 'MOV',
#   'node_type': 'name',
#   'parent_type': 'expr',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200082',
#   'modification_type': 'UPD',
#   'node_type': 'operator',
#   'parent_type': 'expr',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200083',
#   'modification_type': 'MOV',
#   'node_type': 'operator',
#   'parent_type': 'expr',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200084',
#   'modification_type': 'INS',
#   'node_type': 'literal',
#   'parent_type': 'expr',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200085',
#   'modification_type': 'UPD',
#   'node_type': 'name',
#   'parent_type': 'expr',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200086',
#   'modification_type': 'MOV',
#   'node_type': 'name',
#   'parent_type': 'expr',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200087',
#   'modification_type': 'UPD',
#   'node_type': 'operator',
#   'parent_type': 'expr',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200088',
#   'modification_type': 'MOV',
#   'node_type': 'operator',
#   'parent_type': 'expr',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200089',
#   'modification_type': 'UPD',
#   'node_type': 'name',
#   'parent_type': 'expr',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'},
#  {'during_competition': 0,
#   'file_name': 'Tanmoy_26049_17974749_621.src',
#   'idx': '179747490200090',
#   'modification_type': 'MOV',
#   'node_type': 'name',
#   'parent_type': 'expr',
#   'problem_id': '-',
#   'user_name': 'Tanmoy_26049'}]

# %%
def exec_sql(command):
    cur.execute(command)
    return cur.fetchall()

# %%
import pandas as pd
df = pd.DataFrame(rows)
df
# Out:
#     during_competition                      file_name              idx  \
# 0                    0  Tanmoy_26049_17974710_621.src  179747100100000
# 1                    0  Tanmoy_26049_17974710_621.src  179747100100001
# 2                    0  Tanmoy_26049_17974710_621.src  179747100100002
# 3                    0  Tanmoy_26049_17974710_621.src  179747100100003
# 4                    0  Tanmoy_26049_17974710_621.src  179747100100004
# 5                    0  Tanmoy_26049_17974710_621.src  179747100100005
# 6                    0  Tanmoy_26049_17974710_621.src  179747100100006
# 7                    0  Tanmoy_26049_17974710_621.src  179747100100007
# 8                    0  Tanmoy_26049_17974710_621.src  179747100100008
# 9                    0  Tanmoy_26049_17974749_621.src  179747490200000
# 10                   0  Tanmoy_26049_17974749_621.src  179747490200001
# 11                   0  Tanmoy_26049_17974749_621.src  179747490200002
# 12                   0  Tanmoy_26049_17974749_621.src  179747490200003
# 13                   0  Tanmoy_26049_17974749_621.src  179747490200004
# 14                   0  Tanmoy_26049_17974749_621.src  179747490200005
# 15                   0  Tanmoy_26049_17974749_621.src  179747490200006
# 16                   0  Tanmoy_26049_17974749_621.src  179747490200007
# 17                   0  Tanmoy_26049_17974749_621.src  179747490200008
# 18                   0  Tanmoy_26049_17974749_621.src  179747490200009
# 19                   0  Tanmoy_26049_17974749_621.src  179747490200010
# 20                   0  Tanmoy_26049_17974749_621.src  179747490200011
# 21                   0  Tanmoy_26049_17974749_621.src  179747490200012
# 22                   0  Tanmoy_26049_17974749_621.src  179747490200013
# 23                   0  Tanmoy_26049_17974749_621.src  179747490200014
# 24                   0  Tanmoy_26049_17974749_621.src  179747490200015
# 25                   0  Tanmoy_26049_17974749_621.src  179747490200016
# 26                   0  Tanmoy_26049_17974749_621.src  179747490200017
# 27                   0  Tanmoy_26049_17974749_621.src  179747490200018
# 28                   0  Tanmoy_26049_17974749_621.src  179747490200019
# 29                   0  Tanmoy_26049_17974749_621.src  179747490200020
# ..                 ...                            ...              ...
# 70                   0  Tanmoy_26049_17974749_621.src  179747490200061
# 71                   0  Tanmoy_26049_17974749_621.src  179747490200062
# 72                   0  Tanmoy_26049_17974749_621.src  179747490200063
# 73                   0  Tanmoy_26049_17974749_621.src  179747490200064
# 74                   0  Tanmoy_26049_17974749_621.src  179747490200065
# 75                   0  Tanmoy_26049_17974749_621.src  179747490200066
# 76                   0  Tanmoy_26049_17974749_621.src  179747490200067
# 77                   0  Tanmoy_26049_17974749_621.src  179747490200068
# 78                   0  Tanmoy_26049_17974749_621.src  179747490200069
# 79                   0  Tanmoy_26049_17974749_621.src  179747490200070
# 80                   0  Tanmoy_26049_17974749_621.src  179747490200071
# 81                   0  Tanmoy_26049_17974749_621.src  179747490200072
# 82                   0  Tanmoy_26049_17974749_621.src  179747490200073
# 83                   0  Tanmoy_26049_17974749_621.src  179747490200074
# 84                   0  Tanmoy_26049_17974749_621.src  179747490200075
# 85                   0  Tanmoy_26049_17974749_621.src  179747490200076
# 86                   0  Tanmoy_26049_17974749_621.src  179747490200077
# 87                   0  Tanmoy_26049_17974749_621.src  179747490200078
# 88                   0  Tanmoy_26049_17974749_621.src  179747490200079
# 89                   0  Tanmoy_26049_17974749_621.src  179747490200080
# 90                   0  Tanmoy_26049_17974749_621.src  179747490200081
# 91                   0  Tanmoy_26049_17974749_621.src  179747490200082
# 92                   0  Tanmoy_26049_17974749_621.src  179747490200083
# 93                   0  Tanmoy_26049_17974749_621.src  179747490200084
# 94                   0  Tanmoy_26049_17974749_621.src  179747490200085
# 95                   0  Tanmoy_26049_17974749_621.src  179747490200086
# 96                   0  Tanmoy_26049_17974749_621.src  179747490200087
# 97                   0  Tanmoy_26049_17974749_621.src  179747490200088
# 98                   0  Tanmoy_26049_17974749_621.src  179747490200089
# 99                   0  Tanmoy_26049_17974749_621.src  179747490200090
#
#    modification_type  node_type parent_type problem_id     user_name
# 0                INS       else          if          -  Tanmoy_26049
# 1                INS      block        else          -  Tanmoy_26049
# 2                INS  expr_stmt       block          -  Tanmoy_26049
# 3                INS       expr   expr_stmt          -  Tanmoy_26049
# 4                INS       name        expr          -  Tanmoy_26049
# 5                INS   operator        expr          -  Tanmoy_26049
# 6                INS       name        expr          -  Tanmoy_26049
# 7                INS   operator        expr          -  Tanmoy_26049
# 8                INS       name        expr          -  Tanmoy_26049
# 9                INS  decl_stmt       block          -  Tanmoy_26049
# 10               INS        for       block          -  Tanmoy_26049
# 11               INS        for       block          -  Tanmoy_26049
# 12               INS        for       block          -  Tanmoy_26049
# 13               MOV  expr_stmt       block          -  Tanmoy_26049
# 14               INS       decl   decl_stmt          -  Tanmoy_26049
# 15               INS       decl   decl_stmt          -  Tanmoy_26049
# 16               MOV       decl   decl_stmt          -  Tanmoy_26049
# 17               INS       decl   decl_stmt          -  Tanmoy_26049
# 18               INS       decl   decl_stmt          -  Tanmoy_26049
# 19               INS    control         for          -  Tanmoy_26049
# 20               MOV      block         for          -  Tanmoy_26049
# 21               INS    control         for          -  Tanmoy_26049
# 22               INS      block         for          -  Tanmoy_26049
# 23               MOV    control         for          -  Tanmoy_26049
# 24               INS      block         for          -  Tanmoy_26049
# 25               UPD       name        decl          -  Tanmoy_26049
# 26               UPD       name        decl          -  Tanmoy_26049
# 27               INS       type        decl          -  Tanmoy_26049
# 28               INS       name        decl          -  Tanmoy_26049
# 29               INS       init        decl          -  Tanmoy_26049
# ..               ...        ...         ...        ...           ...
# 70               INS       name        type          -  Tanmoy_26049
# 71               INS       expr        init          -  Tanmoy_26049
# 72               INS       expr   condition          -  Tanmoy_26049
# 73               INS       expr        incr          -  Tanmoy_26049
# 74               INS       expr        init          -  Tanmoy_26049
# 75               INS       expr   condition          -  Tanmoy_26049
# 76               INS       expr        incr          -  Tanmoy_26049
# 77               INS    control         for          -  Tanmoy_26049
# 78               MOV      block         for          -  Tanmoy_26049
# 79               INS  condition          if          -  Tanmoy_26049
# 80               INS       then          if          -  Tanmoy_26049
# 81               INS       expr   expr_stmt          -  Tanmoy_26049
# 82               MOV       expr        init          -  Tanmoy_26049
# 83               INS    control         for          -  Tanmoy_26049
# 84               INS      block         for          -  Tanmoy_26049
# 85               INS  condition          if          -  Tanmoy_26049
# 86               INS       then          if          -  Tanmoy_26049
# 87               INS    literal        expr          -  Tanmoy_26049
# 88               INS    literal        expr          -  Tanmoy_26049
# 89               UPD       name        expr          -  Tanmoy_26049
# 90               MOV       name        expr          -  Tanmoy_26049
# 91               UPD   operator        expr          -  Tanmoy_26049
# 92               MOV   operator        expr          -  Tanmoy_26049
# 93               INS    literal        expr          -  Tanmoy_26049
# 94               UPD       name        expr          -  Tanmoy_26049
# 95               MOV       name        expr          -  Tanmoy_26049
# 96               UPD   operator        expr          -  Tanmoy_26049
# 97               MOV   operator        expr          -  Tanmoy_26049
# 98               UPD       name        expr          -  Tanmoy_26049
# 99               MOV       name        expr          -  Tanmoy_26049
#
# [100 rows x 8 columns]

# %%
import json
modification_dir = '../../data/modification_cache/'
ex_path = modification_dir + '.888.log'

# %%
with open(ex_path) as f:
    text = f.read().replace("'", '"').replace('/', r'\/').replace('(', '[').replace(')', ']')
    data = json.loads(text)

# %%
data[0]
# Out:
# ['55D',
#  '213B',
#  '166E',
#  '205B',
#  '359C',
#  '551D',
#  '285C',
#  '476C',
#  '313C',
#  '678D',
#  '27E',
#  '346C',
#  '462B',
#  '165C',
#  '623B',
#  '660E',
#  '714A',
#  '714B',
#  '714C',
#  '716A',
#  '716B',
#  '721A',
#  '721B',
#  '721C',
#  '724A',
#  '724B']

# %%
data[1]
# Out:
# [['src/.888_18870101_55.src'],
#  ['src/.888_18918205_213.src',
#   'src/.888_18918806_213.src',
#   'src/.888_18918886_213.src'],
#  ['src/.888_18922998_166.src',
#   'src/.888_18923131_166.src',
#   'src/.888_18926443_166.src'],
#  ['src/.888_18959763_205.src'],
#  ['src/.888_18964127_359.src', 'src/.888_18964164_359.src'],
#  ['src/.888_18965465_551.src',
#   'src/.888_18965509_551.src',
#   'src/.888_18965625_551.src',
#   'src/.888_18965691_551.src',
#   'src/.888_18965716_551.src',
#   'src/.888_18965741_551.src',
#   'src/.888_18966031_551.src',
#   'src/.888_18966080_551.src',
#   'src/.888_18966122_551.src'],
#  ['src/.888_19304298_285.src'],
#  ['src/.888_19305418_476.src',
#   'src/.888_19305437_476.src',
#   'src/.888_19305474_476.src',
#   'src/.888_19305486_476.src',
#   'src/.888_19305609_476.src'],
#  ['src/.888_19311888_313.src'],
#  ['src/.888_19314109_678.src',
#   'src/.888_19314186_678.src',
#   'src/.888_19314295_678.src',
#   'src/.888_19314308_678.src'],
#  ['src/.888_19343213_27.src', 'src/.888_19464749_27.src'],
#  ['src/.888_19347706_346.src', 'src/.888_19347951_346.src'],
#  ['src/.888_19365507_462.src'],
#  ['src/.888_19465762_165.src', 'src/.888_19465781_165.src'],
#  ['src/.888_19473894_623.src'],
#  ['src/.888_19495756_660.src',
#   'src/.888_19496423_660.src',
#   'src/.888_19496613_660.src'],
#  ['src/.888_20575138_714.src',
#   'src/.888_20576121_714.src',
#   'src/.888_20579874_714.src'],
#  ['src/.888_20584273_714.src',
#   'src/.888_20593788_714.src',
#   'src/.888_20594391_714.src'],
#  ['src/.888_20592040_714.src'],
#  ['src/.888_20686303_716.src'],
#  ['src/.888_20694614_716.src',
#   'src/.888_20695166_716.src',
#   'src/.888_20695530_716.src',
#   'src/.888_20697889_716.src'],
#  ['src/.888_21018228_721.src'],
#  ['src/.888_21022398_721.src',
#   'src/.888_21023595_721.src',
#   'src/.888_21026433_721.src'],
#  ['src/.888_21034949_721.src',
#   'src/.888_21036625_721.src',
#   'src/.888_21037357_721.src',
#   'src/.888_21037906_721.src',
#   'src/.888_21038058_721.src',
#   'src/.888_21038832_721.src',
#   'src/.888_21039675_721.src',
#   'src/.888_21039834_721.src'],
#  ['src/.888_21284558_724.src'],
#  ['src/.888_21286186_724.src']]

# %%
data[2]
# Out:
# [[],
#  [[{'info': ['expr_stmt', 'block', 'function', 'unit'], 'type': 'INS'},
#    {'info': ['macro', 'block', 'function', 'unit'], 'type': 'INS'},
#    {'info': ['block', 'block', 'function', 'unit'], 'type': 'INS'},
#    {'info': ['expr', 'expr_stmt', 'block', 'function', 'unit'], 'type': 'INS'},
#    {'info': ['name', 'macro', 'block', 'function', 'unit'], 'type': 'INS'},
#    {'info': ['argument_list', 'macro', 'block', 'function', 'unit'],
#     'type': 'INS'},
#    {'info': ['macro', 'block', 'function', 'unit'], 'type': 'MOV'},
#    {'info': ['block', 'block', 'block', 'function', 'unit'], 'type': 'INS'},
#    {'info': ['name', 'expr', 'expr_stmt', 'block', 'function', 'unit'],
#     'type': 'INS'},
#    {'info': ['operator', 'expr', 'expr_stmt', 'block', 'function', 'unit'],
#     'type': 'INS'},
#    {'info': ['literal', 'expr', 'expr_stmt', 'block', 'function', 'unit'],
#     'type': 'INS'},
#    {'info': ['argument',
#      'argument_list',
#      'macro',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['argument',
#      'argument_list',
#      'macro',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['argument',
#      'argument_list',
#      'macro',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['expr_stmt', 'block', 'block', 'block', 'function', 'unit'],
#     'type': 'INS'},
#    {'info': ['macro', 'block', 'block', 'block', 'function', 'unit'],
#     'type': 'MOV'},
#    {'info': ['block', 'block', 'block', 'block', 'function', 'unit'],
#     'type': 'INS'},
#    {'info': ['name', 'name', 'expr', 'expr_stmt', 'block', 'function', 'unit'],
#     'type': 'INS'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'function',
#      'unit'],
#     'type': 'MOV'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['literal',
#      'argument',
#      'argument_list',
#      'macro',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['literal',
#      'argument',
#      'argument_list',
#      'macro',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['expr_stmt', 'block', 'function', 'unit'], 'type': 'MOV'},
#    {'info': ['expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['literal',
#      'argument',
#      'argument_list',
#      'macro',
#      'block',
#      'function',
#      'unit'],
#     'type': 'UPD'},
#    {'info': ['expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['literal',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['literal',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'MOV'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['operator', 'expr', 'expr_stmt', 'block', 'function', 'unit'],
#     'type': 'UPD'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'MOV'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'else',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'MOV'},
#    {'info': ['name',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'UPD'},
#    {'info': ['name',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'MOV'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'MOV'},
#    {'info': ['name',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'function',
#      'unit'],
#     'type': 'UPD'},
#    {'info': ['name',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['operator',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['operator',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['literal', 'expr', 'expr_stmt', 'block', 'function', 'unit'],
#     'type': 'MOV'},
#    {'info': ['literal',
#      'argument',
#      'argument_list',
#      'macro',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'name',
#      'expr',
#      'condition',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['literal',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'condition',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['expr',
#      'index',
#      'name',
#      'expr',
#      'condition',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'condition',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'expr',
#      'condition',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['operator',
#      'expr',
#      'condition',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'expr',
#      'condition',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['expr', 'condition', 'if', 'block', 'block', 'function', 'unit'],
#     'type': 'DEL'},
#    {'info': ['condition', 'if', 'block', 'block', 'function', 'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['literal',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['literal',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['block', 'then', 'if', 'block', 'block', 'function', 'unit'],
#     'type': 'DEL'},
#    {'info': ['then', 'if', 'block', 'block', 'function', 'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'else',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['literal',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'else',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'else',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'else',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'else',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'else',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['literal',
#      'expr',
#      'expr_stmt',
#      'block',
#      'else',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['expr',
#      'expr_stmt',
#      'block',
#      'else',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['expr_stmt',
#      'block',
#      'else',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['block', 'else', 'if', 'block', 'block', 'function', 'unit'],
#     'type': 'DEL'},
#    {'info': ['else', 'if', 'block', 'block', 'function', 'unit'],
#     'type': 'DEL'},
#    {'info': ['if', 'block', 'block', 'function', 'unit'], 'type': 'DEL'},
#    {'info': ['name', 'macro', 'block', 'block', 'function', 'unit'],
#     'type': 'DEL'},
#    {'info': ['argument',
#      'argument_list',
#      'macro',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['literal',
#      'argument',
#      'argument_list',
#      'macro',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['argument',
#      'argument_list',
#      'macro',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['literal',
#      'argument',
#      'argument_list',
#      'macro',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['argument',
#      'argument_list',
#      'macro',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['argument_list', 'macro', 'block', 'block', 'function', 'unit'],
#     'type': 'DEL'},
#    {'info': ['macro', 'block', 'block', 'function', 'unit'], 'type': 'DEL'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['literal',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['expr_stmt', 'block', 'block', 'block', 'function', 'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['operator',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['operator',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['literal',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['block', 'block', 'block', 'block', 'function', 'unit'],
#     'type': 'DEL'},
#    {'info': ['block', 'block', 'block', 'function', 'unit'], 'type': 'DEL'},
#    {'info': ['name',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['literal',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['literal',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['expr', 'expr_stmt', 'block', 'block', 'function', 'unit'],
#     'type': 'DEL'},
#    {'info': ['expr_stmt', 'block', 'block', 'function', 'unit'],
#     'type': 'DEL'},
#    {'info': ['name', 'expr', 'expr_stmt', 'block', 'function', 'unit'],
#     'type': 'DEL'},
#    {'info': ['operator', 'expr', 'expr_stmt', 'block', 'function', 'unit'],
#     'type': 'DEL'},
#    {'info': ['name', 'expr', 'expr_stmt', 'block', 'function', 'unit'],
#     'type': 'DEL'},
#    {'info': ['expr', 'expr_stmt', 'block', 'function', 'unit'], 'type': 'DEL'},
#    {'info': ['expr_stmt', 'block', 'function', 'unit'], 'type': 'DEL'}],
#   [{'info': ['macro', 'block', 'block', 'function', 'unit'], 'type': 'MOV'},
#    {'info': ['block', 'block', 'block', 'function', 'unit'], 'type': 'MOV'},
#    {'info': ['if', 'block', 'block', 'function', 'unit'], 'type': 'INS'},
#    {'info': ['if', 'block', 'block', 'function', 'unit'], 'type': 'INS'},
#    {'info': ['macro', 'block', 'block', 'function', 'unit'], 'type': 'INS'},
#    {'info': ['block', 'block', 'block', 'function', 'unit'], 'type': 'INS'},
#    {'info': ['expr_stmt', 'block', 'block', 'function', 'unit'],
#     'type': 'INS'},
#    {'info': ['condition', 'if', 'block', 'block', 'function', 'unit'],
#     'type': 'INS'},
#    {'info': ['then', 'if', 'block', 'block', 'function', 'unit'],
#     'type': 'INS'},
#    {'info': ['condition', 'if', 'block', 'block', 'function', 'unit'],
#     'type': 'INS'},
#    {'info': ['then', 'if', 'block', 'block', 'function', 'unit'],
#     'type': 'INS'},
#    {'info': ['else', 'if', 'block', 'block', 'function', 'unit'],
#     'type': 'INS'},
#    {'info': ['name', 'macro', 'block', 'block', 'function', 'unit'],
#     'type': 'INS'},
#    {'info': ['argument_list', 'macro', 'block', 'block', 'function', 'unit'],
#     'type': 'INS'},
#    {'info': ['expr_stmt', 'block', 'block', 'block', 'function', 'unit'],
#     'type': 'INS'},
#    {'info': ['macro', 'block', 'block', 'block', 'function', 'unit'],
#     'type': 'MOV'},
#    {'info': ['block', 'block', 'block', 'block', 'function', 'unit'],
#     'type': 'INS'},
#    {'info': ['expr', 'expr_stmt', 'block', 'block', 'function', 'unit'],
#     'type': 'INS'},
#    {'info': ['literal',
#      'argument',
#      'argument_list',
#      'macro',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['expr', 'condition', 'if', 'block', 'block', 'function', 'unit'],
#     'type': 'INS'},
#    {'info': ['block', 'then', 'if', 'block', 'block', 'function', 'unit'],
#     'type': 'INS'},
#    {'info': ['literal',
#      'argument',
#      'argument_list',
#      'macro',
#      'block',
#      'function',
#      'unit'],
#     'type': 'UPD'},
#    {'info': ['expr', 'condition', 'if', 'block', 'block', 'function', 'unit'],
#     'type': 'INS'},
#    {'info': ['block', 'then', 'if', 'block', 'block', 'function', 'unit'],
#     'type': 'INS'},
#    {'info': ['block', 'else', 'if', 'block', 'block', 'function', 'unit'],
#     'type': 'INS'},
#    {'info': ['argument',
#      'argument_list',
#      'macro',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['argument',
#      'argument_list',
#      'macro',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['argument',
#      'argument_list',
#      'macro',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['literal',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'MOV'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'UPD'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'MOV'},
#    {'info': ['literal',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'MOV'},
#    {'info': ['expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'MOV'},
#    {'info': ['name',
#      'expr',
#      'condition',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['operator',
#      'expr',
#      'condition',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'expr',
#      'condition',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['expr_stmt',
#      'block',
#      'else',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['literal',
#      'argument',
#      'argument_list',
#      'macro',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['literal',
#      'argument',
#      'argument_list',
#      'macro',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['literal',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'UPD'},
#    {'info': ['name',
#      'name',
#      'expr',
#      'condition',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'condition',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['expr',
#      'expr_stmt',
#      'block',
#      'else',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'MOV'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'MOV'},
#    {'info': ['name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'UPD'},
#    {'info': ['literal',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'MOV'},
#    {'info': ['expr',
#      'index',
#      'name',
#      'expr',
#      'condition',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['literal',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'else',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'else',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['literal',
#      'expr',
#      'expr_stmt',
#      'block',
#      'else',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'MOV'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'MOV'},
#    {'info': ['name',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['literal',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'UPD'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'function',
#      'unit'],
#     'type': 'MOV'},
#    {'info': ['literal',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'condition',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'MOV'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'else',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'MOV'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'else',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'else',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['operator',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['operator',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['literal',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'UPD'},
#    {'info': ['literal',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['literal',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'else',
#      'if',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['operator',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['operator',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'expr',
# ...
#     'type': 'MOV'},
#    {'info': ['operator', 'expr', 'expr_stmt', 'block', 'function', 'unit'],
#     'type': 'MOV'},
#    {'info': ['operator', 'expr', 'expr_stmt', 'block', 'function', 'unit'],
#     'type': 'MOV'},
#    {'info': ['name', 'expr', 'expr_stmt', 'block', 'function', 'unit'],
#     'type': 'MOV'},
#    {'info': ['operator', 'expr', 'expr_stmt', 'block', 'function', 'unit'],
#     'type': 'MOV'},
#    {'info': ['literal', 'expr', 'expr_stmt', 'block', 'function', 'unit'],
#     'type': 'MOV'},
#    {'info': ['operator', 'expr', 'expr_stmt', 'block', 'function', 'unit'],
#     'type': 'MOV'},
#    {'info': ['operator', 'expr', 'expr_stmt', 'block', 'function', 'unit'],
#     'type': 'MOV'},
#    {'info': ['name', 'expr', 'expr_stmt', 'block', 'function', 'unit'],
#     'type': 'MOV'},
#    {'info': ['operator', 'expr', 'expr_stmt', 'block', 'function', 'unit'],
#     'type': 'MOV'},
#    {'info': ['name', 'expr', 'expr_stmt', 'block', 'function', 'unit'],
#     'type': 'MOV'},
#    {'info': ['expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'name',
#      'expr',
#      'init',
#      'decl',
#      'decl_stmt',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'init',
#      'decl',
#      'decl_stmt',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['literal',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['expr',
#      'index',
#      'name',
#      'expr',
#      'init',
#      'decl',
#      'decl_stmt',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name', 'expr', 'expr_stmt', 'block', 'function', 'unit'],
#     'type': 'UPD'},
#    {'info': ['name', 'expr', 'expr_stmt', 'block', 'function', 'unit'],
#     'type': 'MOV'},
#    {'info': ['name', 'expr', 'expr_stmt', 'block', 'function', 'unit'],
#     'type': 'DEL'},
#    {'info': ['operator', 'expr', 'expr_stmt', 'block', 'function', 'unit'],
#     'type': 'DEL'},
#    {'info': ['operator', 'expr', 'expr_stmt', 'block', 'function', 'unit'],
#     'type': 'DEL'},
#    {'info': ['literal', 'expr', 'expr_stmt', 'block', 'function', 'unit'],
#     'type': 'DEL'},
#    {'info': ['operator', 'expr', 'expr_stmt', 'block', 'function', 'unit'],
#     'type': 'DEL'},
#    {'info': ['literal', 'expr', 'expr_stmt', 'block', 'function', 'unit'],
#     'type': 'DEL'},
#    {'info': ['operator', 'expr', 'expr_stmt', 'block', 'function', 'unit'],
#     'type': 'DEL'},
#    {'info': ['expr', 'expr_stmt', 'block', 'function', 'unit'], 'type': 'DEL'},
#    {'info': ['expr_stmt', 'block', 'function', 'unit'], 'type': 'DEL'}]],
#  [[{'info': ['name',
#      'expr',
#      'condition',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'MOV'},
#    {'info': ['operator',
#      'expr',
#      'condition',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'MOV'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'MOV'},
#    {'info': ['name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'MOV'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'MOV'},
#    {'info': ['name',
#      'expr',
#      'condition',
#      'if',
#      'elseif',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'MOV'},
#    {'info': ['name',
#      'expr',
#      'condition',
#      'if',
#      'elseif',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'MOV'},
#    {'info': ['name',
#      'expr',
#      'condition',
#      'if',
#      'elseif',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'MOV'},
#    {'info': ['operator',
#      'expr',
#      'condition',
#      'if',
#      'elseif',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'condition',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'UPD'},
#    {'info': ['name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'elseif',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'MOV'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'elseif',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'MOV'},
#    {'info': ['name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'elseif',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'MOV'},
#    {'info': ['operator',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'elseif',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'MOV'},
#    {'info': ['operator',
#      'expr',
#      'condition',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['operator',
#      'expr',
#      'condition',
#      'if',
#      'elseif',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'}],
#   [{'info': ['name', 'type', 'decl', 'decl_stmt', 'unit'], 'type': 'UPD'},
#    {'info': ['name', 'type', 'decl', 'decl_stmt', 'unit'], 'type': 'UPD'},
#    {'info': ['name',
#      'expr',
#      'argument',
#      'argument_list',
#      'name',
#      'type',
#      'typedef',
#      'unit'],
#     'type': 'UPD'},
#    {'info': ['name',
#      'expr',
#      'argument',
#      'argument_list',
#      'name',
#      'type',
#      'typedef',
#      'unit'],
#     'type': 'UPD'},
#    {'info': ['name',
#      'type',
#      'decl',
#      'decl_stmt',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'UPD'}],
#   [{'info': ['name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['literal',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'}],
#   [{'info': ['expr_stmt', 'block', 'function', 'unit'], 'type': 'INS'},
#    {'info': ['expr', 'expr_stmt', 'block', 'function', 'unit'], 'type': 'INS'},
#    {'info': ['name', 'expr', 'expr_stmt', 'block', 'function', 'unit'],
#     'type': 'INS'},
#    {'info': ['operator', 'expr', 'expr_stmt', 'block', 'function', 'unit'],
#     'type': 'INS'},
#    {'info': ['literal', 'expr', 'expr_stmt', 'block', 'function', 'unit'],
#     'type': 'INS'},
#    {'info': ['name', 'name', 'expr', 'expr_stmt', 'block', 'function', 'unit'],
#     'type': 'INS'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'expr_stmt',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'}],
#   [{'info': ['name',
#      'name',
#      'expr',
#      'argument',
#      'argument_list',
#      'call',
#      'expr',
#      'argument',
#      'argument_list',
#      'call',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'UPD'},
#    {'info': ['name',
#      'name',
#      'expr',
#      'argument',
#      'argument_list',
#      'call',
#      'expr',
#      'argument',
#      'argument_list',
#      'call',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'elseif',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'UPD'}],
#   [{'info': ['expr_stmt',
#      'block',
#      'then',
#      'if',
#      'elseif',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'MOV'},
#    {'info': ['comment',
#      'block',
#      'then',
#      'if',
#      'elseif',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'INS'},
#    {'info': ['name',
#      'name',
#      'call',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['operator',
#      'name',
#      'call',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'name',
#      'call',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'call',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'call',
#      'expr',
#      'argument',
#      'argument_list',
#      'call',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'name',
#      'expr',
#      'argument',
#      'argument_list',
#      'call',
#      'expr',
#      'argument',
#      'argument_list',
#      'call',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'expr',
#      'index',
#      'name',
#      'expr',
#      'argument',
#      'argument_list',
#      'call',
#      'expr',
#      'argument',
#      'argument_list',
#      'call',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['expr',
#      'index',
#      'name',
#      'expr',
#      'argument',
#      'argument_list',
#      'call',
#      'expr',
#      'argument',
#      'argument_list',
#      'call',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['index',
#      'name',
#      'expr',
#      'argument',
#      'argument_list',
#      'call',
#      'expr',
#      'argument',
#      'argument_list',
#      'call',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'expr',
#      'argument',
#      'argument_list',
#      'call',
#      'expr',
#      'argument',
#      'argument_list',
#      'call',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['expr',
#      'argument',
#      'argument_list',
#      'call',
#      'expr',
#      'argument',
#      'argument_list',
#      'call',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['argument',
#      'argument_list',
#      'call',
#      'expr',
#      'argument',
#      'argument_list',
#      'call',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['name',
#      'expr',
#      'argument',
#      'argument_list',
#      'call',
#      'expr',
#      'argument',
#      'argument_list',
#      'call',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['expr',
#      'argument',
#      'argument_list',
#      'call',
#      'expr',
#      'argument',
#      'argument_list',
#      'call',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['argument',
#      'argument_list',
#      'call',
#      'expr',
#      'argument',
#      'argument_list',
#      'call',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['argument_list',
#      'call',
#      'expr',
#      'argument',
#      'argument_list',
#      'call',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['call',
#      'expr',
#      'argument',
#      'argument_list',
#      'call',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['expr',
#      'argument',
#      'argument_list',
#      'call',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['argument',
#      'argument_list',
#      'call',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['argument_list',
#      'call',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['call',
#      'expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['expr',
#      'expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'},
#    {'info': ['expr_stmt',
#      'block',
#      'then',
#      'if',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'DEL'}],
#   [{'info': ['name',
#      'name',
#      'expr',
#      'argument',
#      'argument_list',
#      'call',
#      'expr',
#      'argument',
#      'argument_list',
#      'call',
#      'expr',
#      'expr_stmt',
#      'block',
#      'block',
#      'while',
#      'block',
#      'function',
#      'unit'],
#     'type': 'UPD'}]],
#  [],
#  []]

# %%
len(data)
# Out:
# 3

# %%
df = pd.DataFrame(data[1], index=data[0])

# %%
df
# Out:
#                               0                          1  \
# 55D    src/.888_18870101_55.src                       None
# 213B  src/.888_18918205_213.src  src/.888_18918806_213.src
# 166E  src/.888_18922998_166.src  src/.888_18923131_166.src
# 205B  src/.888_18959763_205.src                       None
# 359C  src/.888_18964127_359.src  src/.888_18964164_359.src
# 551D  src/.888_18965465_551.src  src/.888_18965509_551.src
# 285C  src/.888_19304298_285.src                       None
# 476C  src/.888_19305418_476.src  src/.888_19305437_476.src
# 313C  src/.888_19311888_313.src                       None
# 678D  src/.888_19314109_678.src  src/.888_19314186_678.src
# 27E    src/.888_19343213_27.src   src/.888_19464749_27.src
# 346C  src/.888_19347706_346.src  src/.888_19347951_346.src
# 462B  src/.888_19365507_462.src                       None
# 165C  src/.888_19465762_165.src  src/.888_19465781_165.src
# 623B  src/.888_19473894_623.src                       None
# 660E  src/.888_19495756_660.src  src/.888_19496423_660.src
# 714A  src/.888_20575138_714.src  src/.888_20576121_714.src
# 714B  src/.888_20584273_714.src  src/.888_20593788_714.src
# 714C  src/.888_20592040_714.src                       None
# 716A  src/.888_20686303_716.src                       None
# 716B  src/.888_20694614_716.src  src/.888_20695166_716.src
# 721A  src/.888_21018228_721.src                       None
# 721B  src/.888_21022398_721.src  src/.888_21023595_721.src
# 721C  src/.888_21034949_721.src  src/.888_21036625_721.src
# 724A  src/.888_21284558_724.src                       None
# 724B  src/.888_21286186_724.src                       None
#
#                               2                          3  \
# 55D                        None                       None
# 213B  src/.888_18918886_213.src                       None
# 166E  src/.888_18926443_166.src                       None
# 205B                       None                       None
# 359C                       None                       None
# 551D  src/.888_18965625_551.src  src/.888_18965691_551.src
# 285C                       None                       None
# 476C  src/.888_19305474_476.src  src/.888_19305486_476.src
# 313C                       None                       None
# 678D  src/.888_19314295_678.src  src/.888_19314308_678.src
# 27E                        None                       None
# 346C                       None                       None
# 462B                       None                       None
# 165C                       None                       None
# 623B                       None                       None
# 660E  src/.888_19496613_660.src                       None
# 714A  src/.888_20579874_714.src                       None
# 714B  src/.888_20594391_714.src                       None
# 714C                       None                       None
# 716A                       None                       None
# 716B  src/.888_20695530_716.src  src/.888_20697889_716.src
# 721A                       None                       None
# 721B  src/.888_21026433_721.src                       None
# 721C  src/.888_21037357_721.src  src/.888_21037906_721.src
# 724A                       None                       None
# 724B                       None                       None
#
#                               4                          5  \
# 55D                        None                       None
# 213B                       None                       None
# 166E                       None                       None
# 205B                       None                       None
# 359C                       None                       None
# 551D  src/.888_18965716_551.src  src/.888_18965741_551.src
# 285C                       None                       None
# 476C  src/.888_19305609_476.src                       None
# 313C                       None                       None
# 678D                       None                       None
# 27E                        None                       None
# 346C                       None                       None
# 462B                       None                       None
# 165C                       None                       None
# 623B                       None                       None
# 660E                       None                       None
# 714A                       None                       None
# 714B                       None                       None
# 714C                       None                       None
# 716A                       None                       None
# 716B                       None                       None
# 721A                       None                       None
# 721B                       None                       None
# 721C  src/.888_21038058_721.src  src/.888_21038832_721.src
# 724A                       None                       None
# 724B                       None                       None
#
#                               6                          7  \
# 55D                        None                       None
# 213B                       None                       None
# 166E                       None                       None
# 205B                       None                       None
# 359C                       None                       None
# 551D  src/.888_18966031_551.src  src/.888_18966080_551.src
# 285C                       None                       None
# 476C                       None                       None
# 313C                       None                       None
# 678D                       None                       None
# 27E                        None                       None
# 346C                       None                       None
# 462B                       None                       None
# 165C                       None                       None
# 623B                       None                       None
# 660E                       None                       None
# 714A                       None                       None
# 714B                       None                       None
# 714C                       None                       None
# 716A                       None                       None
# 716B                       None                       None
# 721A                       None                       None
# 721B                       None                       None
# 721C  src/.888_21039675_721.src  src/.888_21039834_721.src
# 724A                       None                       None
# 724B                       None                       None
#
#                               8
# 55D                        None
# 213B                       None
# 166E                       None
# 205B                       None
# 359C                       None
# 551D  src/.888_18966122_551.src
# 285C                       None
# 476C                       None
# 313C                       None
# 678D                       None
# 27E                        None
# 346C                       None
# 462B                       None
# 165C                       None
# 623B                       None
# 660E                       None
# 714A                       None
# 714B                       None
# 714C                       None
# 716A                       None
# 716B                       None
# 721A                       None
# 721B                       None
# 721C                       None
# 724A                       None
# 724B                       None

# %%
block_set = set()
exprs = set()
for changes_list, src_list in zip(data[2], data[1]):
    for change_types, src, src_nx in zip(changes_list, src_list, src_list[1:]):
        for change in change_types:
            pre_block = False
            for node in change['info']:
                if pre_block:
                    if node == 'expr':
                        exprs.add((src, src_nx))
                    block_set.add(node)
                    pre_block = False
                if node == 'block':
                    pre_block = True

print(exprs)
# Out:
# {('src/.888_19343213_27.src', 'src/.888_19464749_27.src'), ('src/.888_20695530_716.src', 'src/.888_20697889_716.src')}
